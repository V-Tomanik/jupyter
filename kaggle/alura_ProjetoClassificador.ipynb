# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split

# %%
uri= 'https://gist.githubusercontent.com/guilhermesilveira/1b7d5475863c15f484ac495bd70975cf/raw/16aff7a0aee67e7c100a2a48b676a2d2d142f646/projects.csv'
dados = pd.read_csv(uri)
len(dados.index)
# Out:
# 2157

# %%
dados['finished'] = dados['unfinished'].map({0:1,1:0})
dados.head()
# Out:
#    unfinished  expected_hours  price  finished
# 0           1              26    192         0
# 1           1              88   9015         0
# 2           1              89   2577         0
# 3           1              42    275         0
# 4           1              39    170         0

# %%
#Dividimos os dados em teste e treinamento e aplicamos um shufle com a semente 45
train, test = train_test_split(dados,test_size=0.25, random_state = 45)

# %%
plt.scatter(dados['expected_hours'],dados['price'],c=dados['finished'],linewidths = 0.5)

# %% [markdown]
# Se eu tentar colocar um método linear de classificação. Chegaremos a um resultado insatisfatorio pela natureza do problema (TxV exp)
#
# Para saber mais sobre svc ou svm
# https://scikit-learn.org/stable/modules/svm.html
# https://en.wikipedia.org/wiki/Support_vector_machine

# %%
#Support Vector Classification
metodoLinear = LinearSVC
